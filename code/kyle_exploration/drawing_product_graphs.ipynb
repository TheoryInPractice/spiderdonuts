# %%
cd ..
# Out:
# /home/kyle/research/sparkstruck/code

# %%
import struckpod.walks as wks

import common.graphs as gs

import networkx as nx

import common.generators as gen

import matplotlib.pyplot as plt

# %%
dir(gen)
# Out:
# ['BASE_PATH',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs_path',
#  'chamfered_dodecahedron',
#  'fan_graph',
#  'hexagonal_pyramid_prism',
#  'nx',
#  'orthobicupola',
#  'os',
#  'pyramid_prism',
#  'pyramid_prism_3',
#  'pyramid_prism_4',
#  'rhombicuboctahedron',
#  'snowflake',
#  'square_orthobicupola',
#  'tiered_pyramid_prism',
#  'triangular_orthobicupola',
#  'triangular_prism']

# %%
G = gen.triangular_orthobicupola()

# %%
G.nodes()
# Out:
# ['16', '20', '12', '15', '11', '9', '17', '10', '14', '13', '18', '19']

# %%
nx.draw_spring(G)
plt.show()

# %%
nx.draw(G)
plt.show()

# %%
nx.draw_spectral(G)
plt.show()

# %%
Cn = nx.cycle_graph(3)
# H = nx.tensor_product(G,Cn)
H = nx.cartesian_product(G,Cn)
nx.draw_spectral(H)
plt.show()
